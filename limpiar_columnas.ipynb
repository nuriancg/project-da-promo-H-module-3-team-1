# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# reading the file
df_raw_data= pd.read_csv('HR_RAW_DATA.csv', index_col=0)
df_raw_data.head(3)
# Out:
#   Age Attrition BusinessTravel DailyRate                Department  \
# 0  51        No            NaN    684,0$                       NaN
# 1  52        No            NaN    699,0$                       NaN
# 2  42        No  travel_rarely    532,0$   Research & Development
#
#    DistanceFromHome  Education    EducationField  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
#
#   employeenumber  EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  \
# 0          162,0                        1       0         51               3
# 1          259,0                        3       0         65               2
# 2          319,0                        3       0         58               3
#
#    JobLevel              JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0         5   resEArch DIREcToR                 3           NaN       19537,0
# 1         5             ManAGeR                 3           NaN       19999,0
# 2         5             ManaGER                 4       Married       19232,0
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# 1         5678                   0    NaN      NaN                 14
# 2         4933                   1    NaN       No                 11
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
# 1               3,0                         1           NaN                 1
# 2               3,0                         4           NaN                 0
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
# 2              22,0                      3             NaN              22
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
# 2                NaN                       11                    15
#
#   SameAsMonthlyIncome  DateBirth       Salary  \
# 0             19537,0       1972  1000000000$
# 1             19999,0       1971  1000000000$
# 2             19232,0       1981  1000000000$
#
#                         RoleDepartament  NUMBERCHILDREN RemoteWork
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1

# %% [markdown]
# * columna 12

# %%
# Remove  employeecount column
df_raw_data.drop("employeecount", axis = 1, inplace = True)
df_raw_data.head(1)
# Out:
#   Age Attrition BusinessTravel DailyRate Department  DistanceFromHome  \
# 0  51        No            NaN    684,0$        NaN                 6
#
#    Education EducationField employeenumber  EnvironmentSatisfaction  Gender  \
# 0          3            NaN          162,0                        1       0
#
#   HourlyRate  JobInvolvement  JobLevel              JobRole  JobSatisfaction  \
# 0         51               3         5   resEArch DIREcToR                 3
#
#   MaritalStatus MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# 0           NaN       19537,0         6462                   7      Y
#
#   OverTime  PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 0       No                 13               3,0                         3
#
#   StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 0           NaN                 0               NaN                      5
#
#   WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0             3,0              20                NaN                       15
#
#    YEARSWITHCURRMANAGER SameAsMonthlyIncome  DateBirth       Salary  \
# 0                    15             19537,0       1972  1000000000$
#
#   RoleDepartament  NUMBERCHILDREN RemoteWork
# 0             NaN             NaN        Yes

# %% [markdown]
# * columna 14

# %%
df_raw_data['EnvironmentSatisfaction'].head(25)
# Out:
# 0      1
# 1      3
# 2      3
# 3      1
# 4      1
# 5      4
# 6      1
# 7      2
# 8      2
# 9      1
# 10     2
# 11     4
# 12     2
# 13     2
# 14     3
# 15     3
# 16     4
# 17     3
# 18     2
# 19     1
# 20     3
# 21     1
# 22     3
# 23     3
# 24    42
# Name: EnvironmentSatisfaction, dtype: int64

# %%
# Rename
df_raw_data = df_raw_data.rename(columns={'EnvironmentSatisfaction': 'Environment_Satisfaction'})

# ranges and tags
for index, row in df_raw_data.iterrows():
    numero = row['Environment_Satisfaction']
    if numero < 10 and numero not in [2, 3, 4]:
        df_raw_data.loc[index, 'Environment_Satisfaction'] = 1
    elif 10 <= numero <= 20:
        df_raw_data.loc[index, 'Environment_Satisfaction'] = 2
    elif 20 < numero <= 30:
        df_raw_data.loc[index, 'Environment_Satisfaction'] = 3
    elif 30 < numero <= 49:
        df_raw_data.loc[index, 'Environment_Satisfaction'] = 4

# %% [markdown]
# ** la funcion no sirve.

# %%
# def tags(numero):
#     # ranges and tags
#     for index, row in df_raw_data.iterrows():
#         numero = row['Environment_Satisfaction']
#         if numero < 10 and numero not in [2, 3, 4]:
#             df_raw_data.loc[index, 'Environment_Satisfaction'] = 1
#         elif 10 <= numero <= 20:
#             df_raw_data.loc[index, 'Environment_Satisfaction'] = 2
#         elif 20 < numero <= 30:
#             df_raw_data.loc[index, 'Environment_Satisfaction'] = 3
#         elif 30 < numero <= 49:
#             df_raw_data.loc[index, 'Environment_Satisfaction'] = 4

# Applying function
# df_raw_data['Environment_Satisfaction'] = df_raw_data['Environment_Satisfaction'].apply(tags)

# %%
df_raw_data['Environment_Satisfaction'].head(25)
# Out:
# 0     1
# 1     3
# 2     3
# 3     1
# 4     1
# 5     4
# 6     1
# 7     2
# 8     2
# 9     1
# 10    2
# 11    4
# 12    2
# 13    2
# 14    3
# 15    3
# 16    4
# 17    3
# 18    2
# 19    1
# 20    3
# 21    1
# 22    3
# 23    3
# 24    4
# Name: Environment_Satisfaction, dtype: int64

# %% [markdown]
# * columna 15

# %%
# Gender

# Convert to String
df_raw_data['Gender'] = df_raw_data['Gender'].astype(str)

# Changing values
df_raw_data['Gender'] = df_raw_data['Gender'].replace({'0': 'M', '1': 'F'})

# %%
df_raw_data['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# * columna 16

# %%
# Rename
df_raw_data = df_raw_data.rename(columns={'HourlyRate': 'Hourly_Rate'})

# Removing 'Not Available'
df_raw_data['Hourly_Rate'] = df_raw_data['Hourly_Rate'].replace({'Not Available': '99999'})

# Convert to Integer
df_raw_data['Hourly_Rate'] = df_raw_data['Hourly_Rate'].astype(int)

# %% [markdown]
# * columna 17

# %%
# Rename
df_raw_data = df_raw_data.rename(columns={'JobInvolvement': 'Job_Involvement'})

#Convert to Integer
df_raw_data['Job_Involvement'] = df_raw_data['Job_Involvement'].astype(int)

# Checking valid values within the range of (1,5) in the column.
df_raw_data[(df_raw_data['Job_Involvement'] >= 1) & (df_raw_data['Job_Involvement'] <= 5)].head(5)
# Out:
#   Age Attrition BusinessTravel DailyRate                Department  \
# 0  51        No            NaN    684,0$                       NaN
# 1  52        No            NaN    699,0$                       NaN
# 2  42        No  travel_rarely    532,0$   Research & Development
# 3  47        No  travel_rarely    359,0$                       NaN
# 4  46        No            NaN   1319,0$                       NaN
#
#    DistanceFromHome  Education    EducationField employeenumber  \
# 0                 6          3               NaN          162,0
# 1                 1          4     Life Sciences          259,0
# 2                 4          2  Technical Degree          319,0
# 3                 2          4           Medical            NaN
# 4                 3          3  Technical Degree            NaN
#
#    Environment_Satisfaction Gender  Hourly_Rate  Job_Involvement  JobLevel  \
# 0                         1      M           51                3         5
# 1                         3      M           65                2         5
# 2                         3      M           58                3         5
# 3                         1      F           82                3         4
# 4                         1      F           45                4         4
#
#                JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0   resEArch DIREcToR                 3           NaN       19537,0
# 1             ManAGeR                 3           NaN       19999,0
# 2             ManaGER                 4       Married       19232,0
# 3   ReseArCH DIrECtOr                 3       Married       17169,0
# 4     sAleS EXECUtIve                 1      Divorced           NaN
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# 1         5678                   0    NaN      NaN                 14
# 2         4933                   1    NaN       No                 11
# 3        26703                   3      Y      NaN                 19
# 4         7739                   2      Y       No                 12
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
# 1               3,0                         1           NaN                 1
# 2               3,0                         4           NaN                 0
# 3               3,0                         2           NaN                 2
# 4               3,0                         4           NaN                 1
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
# 2              22,0                      3             NaN              22
# 3               NaN                      2             NaN              20
# 4               NaN                      5             3,0              19
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
# 2                NaN                       11                    15
# 3                NaN                        5                     6
# 4                NaN                        2                     8
#
#   SameAsMonthlyIncome  DateBirth       Salary  \
# 0             19537,0       1972  1000000000$
# 1             19999,0       1971  1000000000$
# 2             19232,0       1981  1000000000$
# 3             17169,0       1976  1000000000$
# 4                 NaN       1977  1000000000$
#
#                         RoleDepartament  NUMBERCHILDREN RemoteWork
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1
# 3                                   NaN             NaN      False
# 4                                   NaN             NaN          0

# %% [markdown]
# columna 18

# %%
# Rename
df_raw_data = df_raw_data.rename(columns={'JobLevel': 'Job_Level'})

## Checking valid values within the range of (1,5) in the column.
df_raw_data[(df_raw_data['Job_Level'] >= 1) & (df_raw_data['Job_Level'] <= 5)].head(5)
# Out:
#   Age Attrition BusinessTravel DailyRate                Department  \
# 0  51        No            NaN    684,0$                       NaN
# 1  52        No            NaN    699,0$                       NaN
# 2  42        No  travel_rarely    532,0$   Research & Development
# 3  47        No  travel_rarely    359,0$                       NaN
# 4  46        No            NaN   1319,0$                       NaN
#
#    DistanceFromHome  Education    EducationField employeenumber  \
# 0                 6          3               NaN          162,0
# 1                 1          4     Life Sciences          259,0
# 2                 4          2  Technical Degree          319,0
# 3                 2          4           Medical            NaN
# 4                 3          3  Technical Degree            NaN
#
#    Environment_Satisfaction Gender  Hourly_Rate  Job_Involvement  Job_Level  \
# 0                         1      M           51                3          5
# 1                         3      M           65                2          5
# 2                         3      M           58                3          5
# 3                         1      F           82                3          4
# 4                         1      F           45                4          4
#
#                JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0   resEArch DIREcToR                 3           NaN       19537,0
# 1             ManAGeR                 3           NaN       19999,0
# 2             ManaGER                 4       Married       19232,0
# 3   ReseArCH DIrECtOr                 3       Married       17169,0
# 4     sAleS EXECUtIve                 1      Divorced           NaN
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# 1         5678                   0    NaN      NaN                 14
# 2         4933                   1    NaN       No                 11
# 3        26703                   3      Y      NaN                 19
# 4         7739                   2      Y       No                 12
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
# 1               3,0                         1           NaN                 1
# 2               3,0                         4           NaN                 0
# 3               3,0                         2           NaN                 2
# 4               3,0                         4           NaN                 1
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
# 2              22,0                      3             NaN              22
# 3               NaN                      2             NaN              20
# 4               NaN                      5             3,0              19
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
# 2                NaN                       11                    15
# 3                NaN                        5                     6
# 4                NaN                        2                     8
#
#   SameAsMonthlyIncome  DateBirth       Salary  \
# 0             19537,0       1972  1000000000$
# 1             19999,0       1971  1000000000$
# 2             19232,0       1981  1000000000$
# 3             17169,0       1976  1000000000$
# 4                 NaN       1977  1000000000$
#
#                         RoleDepartament  NUMBERCHILDREN RemoteWork
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1
# 3                                   NaN             NaN      False
# 4                                   NaN             NaN          0

# %% [markdown]
# * columna 19

# %%
# Rename
df_raw_data = df_raw_data.rename(columns={'JobRole': 'Job_Role'})

# Sorting column values
df_raw_data['Job_Role'] = df_raw_data['Job_Role'].str.title()

# %%
df_raw_data['Job_Role'].unique()
# Out:
# array([' Research Director ', ' Manager ', ' Sales Executive ',
#        ' Manufacturing Director ', ' Research Scientist ',
#        ' Healthcare Representative ', ' Laboratory Technician ',
#        ' Sales Representative ', ' Human Resources '], dtype=object)

# %%
df_raw_data['JobSatisfaction'].unique()
# Out:
# array([3, 4, 1, 2], dtype=int64)

# %% [markdown]
# columna 20

# %%
#Rename
df_raw_data = df_raw_data.rename(columns={'JobSatisfaction': 'Job_Satisfaction'})

# Checking valid values within the range of (1,5) in the column.
df_raw_data[(df_raw_data['Job_Satisfaction'] >= 1) & (df_raw_data['Job_Satisfaction'] <= 5)].head(25)
# Out:
#    Age Attrition     BusinessTravel DailyRate                Department  \
# 0   51        No                NaN    684,0$                       NaN
# 1   52        No                NaN    699,0$                       NaN
# 2   42        No      travel_rarely    532,0$   Research & Development
# 3   47        No      travel_rarely    359,0$                       NaN
# 4   46        No                NaN   1319,0$                       NaN
# 5   48        No                NaN    117,0$   Research & Development
# 6   59        No                NaN   1435,0$                       NaN
# 7   42        No      travel_rarely    635,0$                       NaN
# 8   41        No                NaN   1276,0$                       NaN
# 9   41        No  travel_frequently    840,0$                       NaN
# 10  41        No         non-travel    247,0$                       NaN
# 11  56        No      travel_rarely   1369,0$                       NaN
# 12  38        No                NaN    201,0$                       NaN
# 13  41       Yes      travel_rarely   1360,0$                       NaN
# 14  55        No                NaN    692,0$                       NaN
# 15  40        No      travel_rarely   1398,0$                       NaN
# 16  58       Yes      travel_rarely    286,0$                       NaN
# 17  46        No      travel_rarely   1402,0$                       NaN
# 18  35        No                NaN    819,0$                       NaN
# 19  40        No      travel_rarely    884,0$                       NaN
# 20  45        No         non-travel   1238,0$   Research & Development
# 21  33        No                NaN    515,0$                       NaN
# 22  36        No                NaN   1223,0$                       NaN
# 23  47        No                NaN    202,0$                       NaN
# 24  36        No      travel_rarely    928,0$                       NaN
#
#     DistanceFromHome  Education    EducationField employeenumber  \
# 0                  6          3               NaN          162,0
# 1                  1          4     Life Sciences          259,0
# 2                  4          2  Technical Degree          319,0
# 3                  2          4           Medical            NaN
# 4                  3          3  Technical Degree            NaN
# 5                 22          3           Medical         1900,0
# 6                 25          3     Life Sciences           81,0
# 7                  1          1               NaN          387,0
# 8                  2          5               NaN            NaN
# 9                  9          3               NaN          999,0
# 10                 7          1               NaN         1035,0
# 11                23          3     Life Sciences            NaN
# 12                10          3           Medical            NaN
# 13                12          3               NaN           58,0
# 14                14          4           Medical            NaN
# 15                 2          4               NaN          558,0
# 16                 2          4               NaN          825,0
# 17                 2          3               NaN            NaN
# 18               -13          5     Life Sciences            NaN
# 19                15          3     Life Sciences            NaN
# 20                 1          1               NaN         1712,0
# 21                 1          2     Life Sciences           73,0
# 22                 8          3               NaN            NaN
# 23                 2          2             Other          820,0
# 24               -42          2     Life Sciences            NaN
#
#     Environment_Satisfaction Gender  Hourly_Rate  Job_Involvement  Job_Level  \
# 0                          1      M           51                3          5
# 1                          3      M           65                2          5
# 2                          3      M           58                3          5
# 3                          1      F           82                3          4
# 4                          1      F           45                4          4
# 5                          4      F           58                3          4
# 6                          1      F           99                3          3
# 7                          2      M           99                3          2
# 8                          2      F           91                3          4
# 9                          1      M           64                3          5
# 10                         2      F           55                1          5
# 11                         4      M           68                3          4
# 12                         2      F           99                1          3
# 13                         2      F           49                3          5
# 14                         3      M           61                4          5
# 15                         3      F           79                3          5
# 16                         4      M           31                3          5
# 17                         3      F           69                3          4
# 18                         2      M           48                4          2
# 19                         1      F           80                2          3
# 20                         3      M           74                2          3
# 21                         1      F           98                3          3
# 22                         3      F           59                3          3
# 23                         3      F           33                3          4
# 24                         4      M           56                3          2
#
#                        Job_Role  Job_Satisfaction MaritalStatus MonthlyIncome  \
# 0            Research Director                  3           NaN       19537,0
# 1                      Manager                  3           NaN       19999,0
# 2                      Manager                  4       Married       19232,0
# 3            Research Director                  3       Married       17169,0
# 4              Sales Executive                  1      Divorced           NaN
# 5                      Manager                  4           NaN       17174,0
# 6              Sales Executive                  1           NaN           NaN
# 7              Sales Executive                  3       Married           NaN
# 8                      Manager                  1       Married       16595,0
# 9            Research Director                  3           NaN           NaN
# 10           Research Director                  3           NaN       19973,0
# 11      Manufacturing Director                  2       Married       13402,0
# 12           Research Director                  3       Married       13206,0
# 13           Research Director                  3       Married       19545,0
# 14           Research Director                  2        Single           NaN
# 15                     Manager                  3           NaN       18041,0
# 16           Research Director                  2        Single       19246,0
# 17                     Manager                  1           NaN           NaN
# 18          Research Scientist                  1       Married           NaN
# 19      Manufacturing Director                  3           NaN           NaN
# 20   Healthcare Representative                  3           NaN       10748,0
# 21           Research Director                  4        Single           NaN
# 22   Healthcare Representative                  3      Divorced           NaN
# 23                     Manager                  4       Married       16752,0
# 24             Sales Executive                  4           NaN        6201,0
#
#     MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0          6462                   7      Y       No                 13
# 1          5678                   0    NaN      NaN                 14
# 2          4933                   1    NaN       No                 11
# 3         26703                   3      Y      NaN                 19
# 4          7739                   2      Y       No                 12
# 5          2437                   3    NaN       No                 11
# 6          2354                   7      Y      NaN                 11
# 7         24532                   1    NaN       No                 25
# 8          5626                   7    NaN       No                 16
# 9          3735                   2    NaN       No                 17
# 10        20284                   1      Y       No                 22
# 11        18235                   4    NaN      Yes                 12
# 12         3376                   3      Y       No                 12
# 13        16280                   1    NaN       No                 12
# 14        13339                   8    NaN       No                 11
# 15        13022                   0    NaN       No                 14
# 16        25761                   7      Y      Yes                 12
# 17        24097                   8    NaN      NaN                 23
# 18        26312                   1    NaN      NaN                 11
# 19        25800                   1      Y      NaN                 13
# 20         3395                   3      Y      NaN                 23
# 21        15146                   1    NaN      Yes                 12
# 22         8202                   1      Y      NaN                 13
# 23        12982                   1    NaN      NaN                 11
# 24         2823                   1      Y      NaN                 14
#
#    PerformanceRating  RelationshipSatisfaction StandardHours  \
# 0                3,0                         3           NaN
# 1                3,0                         1           NaN
# 2                3,0                         4           NaN
# 3                3,0                         2           NaN
# 4                3,0                         4           NaN
# 5                3,0                         2           NaN
# 6                3,0                         4           NaN
# 7                4,0                         3           NaN
# 8                3,0                         2           NaN
# 9                3,0                         2           NaN
# 10               4,0                         2           NaN
# 11               NaN                         1           NaN
# 12               3,0                         1           NaN
# 13               3,0                         4           NaN
# 14               3,0                         4           NaN
# 15               3,0                         4           NaN
# 16               3,0                         4           NaN
# 17               4,0                         1           NaN
# 18               3,0                         4           NaN
# 19               3,0                         4           NaN
# 20               4,0                         4           NaN
# 21               3,0                         3           NaN
# 22               NaN                         2           NaN
# 23               3,0                         3          80,0
# 24               3,0                         4           NaN
#
#     StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  \
# 0                  0               NaN                      5             3,0
# 1                  1              34,0                      5             3,0
# 2                  0              22,0                      3             NaN
# 3                  2               NaN                      2             NaN
# 4                  1               NaN                      5             3,0
# 5                  1               NaN                      3             3,0
# 6                  0              28,0                      3             2,0
# 7                  0              20,0                      3             3,0
# 8                  1              22,0                      2             3,0
# 9                  1              21,0                      2             4,0
# 10                 2               NaN                      3             3,0
# 11                 1              33,0                      0             3,0
# 12                 1               NaN                      3             3,0
# 13                 0               NaN                      0             3,0
# 14                 0               NaN                      3             3,0
# 15                 0               NaN                      2             3,0
# 16                 0              40,0                      2             3,0
# 17                 0              28,0                      2             3,0
# 18                 0               NaN                      2             3,0
# 19                 2              18,0                      2             NaN
# 20                 1              25,0                      3             2,0
# 21                 0              15,0                      1             3,0
# 22                 3              17,0                      2             3,0
# 23                 1               NaN                      3             2,0
# 24                 1              18,0                      1             NaN
#
#     YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               20                NaN                       15
# 1               33                NaN                       11
# 2               22                NaN                       11
# 3               20                NaN                        5
# 4               19                NaN                        2
# 5               22                NaN                        4
# 6               21                NaN                        7
# 7               20                NaN                       11
# 8               18                NaN                       11
# 9               18                NaN                        0
# 10              21                NaN                        5
# 11              19                NaN                       15
# 12              18                NaN                        1
# 13              22                NaN                       15
# 14              24                NaN                        2
# 15              20                NaN                        1
# 16              31                NaN                       13
# 17              26                NaN                       15
# 18              16                NaN                        1
# 19              18                NaN                       14
# 20              23                NaN                       14
# 21              15                NaN                        8
# 22              17                NaN                       12
# 23              26                NaN                        3
# 24              18                NaN                        4
#
#     YEARSWITHCURRMANAGER SameAsMonthlyIncome  DateBirth       Salary  \
# 0                     15             19537,0       1972  1000000000$
# 1                      9             19999,0       1971  1000000000$
# 2                     15             19232,0       1981  1000000000$
# 3                      6             17169,0       1976  1000000000$
# 4                      8                 NaN       1977  1000000000$
# 5                      7             17174,0       1975  1000000000$
# 6                      9                 NaN       1964  1000000000$
# 7                      6                 NaN       1981  1000000000$
# 8                      8             16595,0       1982  1000000000$
# 9                     11                 NaN       1982  1000000000$
# 10                    10             19973,0       1982  1000000000$
# 11                     9             13402,0       1967  1000000000$
# 12                    11             13206,0       1985  1000000000$
# 13                     8             19545,0       1982  1000000000$
# 14                    15                 NaN       1968  1000000000$
# 15                    12             18041,0       1983  1000000000$
# 16                     8             19246,0       1965  1000000000$
# 17                     9                 NaN       1977  1000000000$
# 18                    10                 NaN       1988  1000000000$
# 19                    12                 NaN       1983  1000000000$
# 20                     4             10748,0       1978  1000000000$
# 21                    12                 NaN       1990  1000000000$
# 22                     8                 NaN       1987  1000000000$
# 23                     0             16752,0       1976  1000000000$
# 24                    11              6201,0       1987  1000000000$
#
#                                       RoleDepartament  NUMBERCHILDREN  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                 ManaGER  -  Research & Development              NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 5                 MANAger  -  Research & Development              NaN
# 6                                                 NaN             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10                                                NaN             NaN
# 11                                                NaN             NaN
# 12                                                NaN             NaN
# 13                                                NaN             NaN
# 14                                                NaN             NaN
# 15                                                NaN             NaN
# 16                                                NaN             NaN
# 17                                                NaN             NaN
# 18                                                NaN             NaN
# 19                                                NaN             NaN
# 20   heaLtHcArE repResENtATiVe  -  Research & Deve...             NaN
# 21                                                NaN             NaN
# 22                                                NaN             NaN
# 23                                                NaN             NaN
# 24                                                NaN             NaN
#
#    RemoteWork
# 0         Yes
# 1           1
# 2           1
# 3       False
# 4           0
# 5         Yes
# 6        True
# 7           0
# 8        True
# 9           0
# 10          0
# 11      False
# 12          1
# 13      False
# 14       True
# 15          0
# 16          0
# 17      False
# 18      False
# 19       True
# 20      False
# 21       True
# 22          1
# 23      False
# 24       True

# %% [markdown]
# columna 21

# %%
# Rename
df_raw_data = df_raw_data.rename(columns={'MaritalStatus': 'Marital_Status'})

# Sorting column values
df_raw_data['Marital_Status'] = df_raw_data['Marital_Status'].str.title()

# Ortografic errors
df_raw_data['Marital_Status']= df_raw_data['Marital_Status'].replace({'Marreid':'Married'})

# %% [markdown]
# * columna 22

# %%
# Rename
df_raw_data = df_raw_data.rename(columns={'MonthlyIncome': 'Monthly_Income'})

# Replace (.)
df_raw_data['Monthly_Income'] = df_raw_data['Monthly_Income'].str.replace(",", ".")

# Convert to float
df_raw_data['Monthly_Income'] = df_raw_data['Monthly_Income'].astype(float)

# %% [markdown]
# columna 23

# %%
# Rename
df_raw_data = df_raw_data.rename(columns={'MonthlyRate': 'Monthly_Rate'})

#Convert to Integer
df_raw_data['Monthly_Rate'] = df_raw_data['Monthly_Rate'].astype(float)

# %%
df_raw_data['Monthly_Income'].isnull().sum()
# Out:
# 843

# %%
df_raw_data['Monthly_Rate'].isnull().sum()
# Out:
# 0

# %%
df_raw_data['DailyRate'].isnull().sum()
# Out:
# 0

# %%
df_raw_data['Monthly_Rate'].head(3) # Tarifa Mensual: Pago basado en los días trabajados en el período.
                                    #Los empleados con tarifa mensual también reciben una cantidad fija, pero esta se calcula en función de los días trabajados.
                                    #Si un empleado tiene una tarifa diaria de $500 y trabaja 10 días, su pago sería de $5,000 (500 * 10).
# Out:
# 0    6462.0
# 1    5678.0
# 2    4933.0
# Name: Monthly_Rate, dtype: float64

# %%
df_raw_data['Monthly_Income'].head(3) #Ingreso Mensual: Pago fijo sin importar los días trabajados.
                                      #Los empleados con ingreso mensual reciben una cantidad fija de dinero cada mes, independientemente del número real de días trabajados en ese período.
                                      #Por ejemplo, si un empleado tiene un ingreso mensual de $15,000
                                      # recibirá la misma cantidad en febrero y marzo, incluso si febrero es un mes más corto que marzo
# Out:
# 0    19537.0
# 1    19999.0
# 2    19232.0
# Name: Monthly_Income, dtype: float64

# %%
df_raw_data.to_csv("df_limpieza_columnas.csv", index=False)
