# %% [markdown]
# # ANÁLISIS A/B TESTING

# %% [markdown]
# ## En nuestro análisis estadístico, estudiamos si hay una diferencia significativa en la tasa de rotación de los empleados según su nivel de satisfacción en la empresa.
#
# H0= Afirmamos que no hay diferencia; la tasa de rotación no afecta al nivel de satisfacción.
# H1= Afirmamos que sí la hay, el nivel de satisfacción afecta significativamente a la tasa de rotación.
#
#
# De las personas que siguen en la empresa, vemos que son más los que se encuentran satisfechos que los que no. En el caso de los que han dejado la empresa, no encontramos en esta primera visualización una relación significativa con el nivel de satisfacción.
#
# ![image.png](attachment:image.png)
#
#
# La tasa de rotación en el Grupo A (satisfaccion igual o mayor a 3) es 13.86%. Frente a la tasa de rotación en el Grupo B(satisfaccion menor a 3), que es de 19.65%. Según estos datos, de las personas que dejaron la empresa, son más los que estaban descontentos.
# ![image-2.png](attachment:image-2.png)
#
# ## TESTS
# - Según el test de Student (con un p_value de 0.004) SÍ hay diferencia significativa entre los grupos. Por lo que se rechaza la H0.
#
# - Z-statistic: (-2.94) Este valor en negativo indica que la proporción de personas que dejaron la empresa en el Grupo A (empleados satisfechos) es menor que en el Grupo B (empleados descontentos). Sugiere que la diferencia es significativa, pero hay menos rotación donde podríamos esperar más, o viceversa.
#
# - P-value del ztest: (0.0032) Se rechaza la hipótesis nula. Indica que es muy improbable que la diferencia en las tasas de rotación entre los dos grupos se deba al azar. Asi que, podemos concluir con bastante seguridad que existe una diferencia significativa en las tasas de rotación entre los empleados satisfechos y el sentimiento de descontento.
#
# - Según el test Chi-squared, con un valor de 8.2479, entendemos que existe una diferencia significativa en los niveles de satisfacción entre los empleados actuales y los exempleados.
#
# ---
# ## PRUEBAS ADICIONALES
# Llevamos a cabo nuevas pruebas para conocer en mayor profundidad las razones por las que hay más empleados descontentos.
#
# Buscamos la relación entre nuestras diferentes variables, y extraemos las siguientes conclusiones:
#
# 1) A más nivel de desempeño, más sube el porcentaje de subida de los salarios. Señal de prácticas saludables de la empresa, que recompensan a los empleados con un buen nivel de desempeño.
#
# 2) A más años trabajados, más aumenta el cargo de las personas empleadas. Lo que indica que la empresa promociona a sus personas trabajadoras a medida que pasa el tiempo.
#
# ![image-3.png](attachment:image-3.png)
#
# 3) A más años trabajados y a más años en la empresa, más años con el/la actual manager. Esto podría indicar que los/las managers mantienen su puesto de trabajo, es decir que hay cierta estabilidad.
#
# ![image-5.png](attachment:image-5.png)
#
# 4) A más edad, más experiencia en diferentes empresas. Los empleados entre 40 y 44 años han trabajado en más empresas que los empleados más jóvenes que ellos.
#
# ![image-4.png](attachment:image-4.png)
#
#
# Tras estos resultados deducimos que, por lo general, la empresa realiza buenas prácticas hacia sus empleados, como la subida de sueldo o de cargo. El descontento de los empleados podría proceder de otras variables que no están sujetas a estudio actualmente, por lo que recomendamos la realización de encuestas a sus empleados, donde estos puedan desarrollar los motivos de su descontento.
