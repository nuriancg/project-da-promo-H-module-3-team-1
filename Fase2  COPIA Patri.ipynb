# %% [markdown]
# ## Employee_Number
# - 1080 valores únicos (incluyendo el 0)
# - 534 duplicados
# - (1080 + 534 = 1614 totales)
# - ...................
# - dtype  -> object

# %% [markdown]
# ## Duplicados
#
# - 431 son 'Employee_Number'= 0
# - 104 en las siguientes situaciones
#
# - df_duplicados = 639 rows -> 431 'Employee_Number'=0 + (104 x 2)

# %% [markdown]
# - Situación 1: 51 employees
#     - Todas las columnas son iguales
#
#     ➡️ Solución: eliminar el primer registro
#
# - Situación 2: 13 employees
#     - Distance_From_Home diferentes
#
#     ➡️ Solución: eliminar el primer registro
#
# - Situación 3: 48 employees
#     - Remote_Work diferentes
#
#     ➡️ Solución: eliminar el primer registro
#
# - Situación 4: 4 employees
#     - Distance_From_Home diferentes
#     - Remote_Work diferentes
#
#     ➡️ Solución: eliminar el primer registro
#
# - Situación 5: 8 employees
#     - Hourly_Rate -> Not Available
#
#     ➡️ Solución: eliminar Hourly_Rate == Not Available
#
# - Situación 6: 12 employees
#     - Distance_From_Home diferentes
#     - Distance_From_Home = Environment_Satisfaction
#
#     ➡️ Solución: eliminar Distance_From_Home = Environment_Satisfaction

# %%
# Importamos librerias
import pandas as pd
import numpy as np

import re

from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# Ajustes de visualización
pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)

# %%
# Leemos el .csv y lo guardamos en una variable df
url_raw_data='https://raw.githubusercontent.com/nuriancg/project-da-promo-H-module-3-team-1/master/HR_RAW_DATA.csv'
df_original = pd.read_csv(url_raw_data, index_col=0)

# %%
#creamos una copia del df con la que trabajaremos
df=df_original.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1614 non-null   object
#  1   Attrition                 1614 non-null   object
#  2   BusinessTravel            842 non-null    object
#  3   DailyRate                 1614 non-null   object
#  4   Department                302 non-null    object
#  5   DistanceFromHome          1614 non-null   int64
#  6   Education                 1614 non-null   int64
#  7   EducationField            869 non-null    object
#  8   employeecount             1614 non-null   int64
#  9   employeenumber            1183 non-null   object
#  10  EnvironmentSatisfaction   1614 non-null   int64
#  11  Gender                    1614 non-null   int64
#  12  HourlyRate                1614 non-null   object
#  13  JobInvolvement            1614 non-null   int64
#  14  JobLevel                  1614 non-null   int64
#  15  JobRole                   1614 non-null   object
#  16  JobSatisfaction           1614 non-null   int64
#  17  MaritalStatus             963 non-null    object
#  18  MonthlyIncome             771 non-null    object
#  19  MonthlyRate               1614 non-null   int64
#  20  NUMCOMPANIESWORKED        1614 non-null   int64
#  21  Over18                    713 non-null    object
#  22  OverTime                  938 non-null    object
#  23  PercentSalaryHike         1614 non-null   int64
#  24  PerformanceRating         1419 non-null   object
#  25  RelationshipSatisfaction  1614 non-null   int64
#  26  StandardHours             419 non-null    object
#  27  StockOptionLevel          1614 non-null   int64
#  28  TOTALWORKINGYEARS         1088 non-null   object
#  29  TrainingTimesLastYear     1614 non-null   int64
#  30  WORKLIFEBALANCE           1506 non-null   object
#  31  YearsAtCompany            1614 non-null   int64
#  32  YearsInCurrentRole        34 non-null     object
#  33  YearsSinceLastPromotion   1614 non-null   int64
#  34  YEARSWITHCURRMANAGER      1614 non-null   int64
#  35  SameAsMonthlyIncome       771 non-null    object
#  36  DateBirth                 1614 non-null   int64
#  37  Salary                    1614 non-null   object
#  38  RoleDepartament           302 non-null    object
#  39  NUMBERCHILDREN            0 non-null      float64
#  40  RemoteWork                1614 non-null   object
# dtypes: float64(1), int64(18), object(22)
# memory usage: 529.6+ KB

# %% [markdown]
# ## Paso 1: Limpieza de datos

# %% [markdown]
# ### 1.1. Modificar nombre columnas

# %%
columnas = df.columns

def normalizar_encabezados(encabezado):
    # Mapeo para palabras completamente en mayúsculas pq no encuentro patrón para dividir.
    casos_especiales = {
        'NUMCOMPANIESWORKED': 'Num_Companies_Worked',
        'TOTALWORKINGYEARS': 'Total_Working_Years',
        'YEARSWITHCURRMANAGER': 'Years_With_Curr_Manager',
        'NUMBERCHILDREN': 'Number_Children', # Añado otros casos especiales, Los pongo en mayúsculas para que los trate trate igual a los anteriores.
        'EMPLOYEECOUNT': 'Employee_Count',
        'EMPLOYEENUMBER': 'Employee_Number',
        'WORKLIFEBALANCE': 'Work_Life_Balance'
    }

    # Si el encabezado está en casos especiales devolver el formato dado.
    if encabezado.upper() in casos_especiales:
        return casos_especiales[encabezado.upper()]

    # Añadir guion bajo entre letras y números
    encabezado = re.sub(r'([a-zA-Z])(\d)', r'\1_\2', encabezado)

    # Para formatos que incluyen transiciones de minúscula a mayúscula
    if re.match(r'^[A-Za-z0-9]+$', encabezado):  # Si son letras seguidas de números sin guiones
        encabezado = re.sub(r'([a-z])([A-Z])', r'\1_\2', encabezado)
        encabezado = re.sub(r'([A-Z]+)([A-Z][a-z]+)', r'\1_\2', encabezado)

    # Capitalizar cada string separado por guiones
    palabras = encabezado.split('_')
    return '_'.join(word.capitalize() for word in palabras)

encabezados_normalizados = [normalizar_encabezados(columna) for columna in columnas]

df.columns= encabezados_normalizados
df.columns
# Out:
# Index(['Age', 'Attrition', 'Business_Travel', 'Daily_Rate', 'Department',
#        'Distance_From_Home', 'Education', 'Education_Field', 'Employee_Count',
#        'Employee_Number', 'Environment_Satisfaction', 'Gender', 'Hourly_Rate',
#        'Job_Involvement', 'Job_Level', 'Job_Role', 'Job_Satisfaction',
#        'Marital_Status', 'Monthly_Income', 'Monthly_Rate',
#        'Num_Companies_Worked', 'Over_18', 'Over_Time', 'Percent_Salary_Hike',
#        'Performance_Rating', 'Relationship_Satisfaction', 'Standard_Hours',
#        'Stock_Option_Level', 'Total_Working_Years', 'Training_Times_Last_Year',
#        'Work_Life_Balance', 'Years_At_Company', 'Years_In_Current_Role',
#        'Years_Since_Last_Promotion', 'Years_With_Curr_Manager',
#        'Same_As_Monthly_Income', 'Date_Birth', 'Salary', 'Role_Departament',
#        'Number_Children', 'Remote_Work'],
#       dtype='object')

# %% [markdown]
# ### 1.2. Eliminar columnas no necesarias

# %%
lista_col_eliminar=['Employee_Count','Over_18','Years_In_Current_Role','Same_As_Monthly_Income','Salary', 'Standard_Hours','Role_Departament', 'Number_Children']

for col in lista_col_eliminar:
    df.drop(col, axis=1, inplace=True)

# %%
df.shape
# Out:
# (1614, 33)

# %% [markdown]
# ### 1.3. Crear columnas nuevas

# %%
df.insert(1, 'Age_Group', '')
df.insert(25,'Satisfaction_Group','')

# %%
df.shape
# Out:
# (1614, 35)

# %% [markdown]
# ### 1.4. Modificar valores en columnas

# %% [markdown]
# 1.4.1 Convertir a str

# %%
lista_col_to_str=['Daily_Rate','Department','Education_Field','Employee_Number','Distance_From_Home','Environment_Satisfaction','Gender','Monthly_Income','Performance_Rating','Remote_Work','Total_Working_Years','Work_Life_Balance' ]

for col in lista_col_to_str:
    df[col] = df[col].astype(str)

# %% [markdown]
# 1.4.2 Cambio de ',' por '.'

# %%
# lista_col_to_punto=['Daily_Rate']

# for col in lista_col_to_punto:
#     df[col] = df[col].str.replace(',','.')

# %% [markdown]
# 1.4.3 Cambio de ',0' por ''

# %%
lista_col_to_no_coma=['Daily_Rate','Employee_Number', 'Monthly_Income','Performance_Rating','Total_Working_Years','Work_Life_Balance']

for col in lista_col_to_no_coma:
    df[col] = df[col].str.replace(',0','')

# %% [markdown]
# 1.4.4 Booleanos

# %%
dict_booleanos = {'1':True, 
                  'Yes':True, 
                  'True':True, 
                  '0':False, 
                  'No':False,
                  'False':False}

lista_col_to_booleanos = ['Attrition', 'Over_Time','Remote_Work']

for col in lista_col_to_booleanos:
    df[col] = df[col].replace(dict_booleanos)

# %% [markdown]
# 1.4.5 Otros cambios

# %%
#Columna 'Age'
reemplazos = {
    'forty-seven': 47,
    'fifty-eight': 58,
    'thirty-six': 36,
    'fifty-five': 55,
    'fifty-two': 52,
    'thirty-one': 31,
    'thirty': 30,
    'twenty-six': 26,
    'thirty-seven': 37,
    'thirty-two': 32,
    'twenty-four': 24
}
df['Age'] = df['Age'].replace(reemplazos)

#Columna 'Business_Travel'
df['Business_Travel'] = df['Business_Travel'].str.replace('-',' ').str.replace('_',' ')

#Columna 'Daily_Rate'
df['Daily_Rate'] = df['Daily_Rate'].str.replace('$', '')

#Columna 'Department'
df['Department']=df['Department'].str.strip()

# Bucle for para rellenar
for index, row in df.iterrows():

    job_role = row['Job_Role'].strip().lower()
    if job_role == 'sales executive':
        df.loc[index, 'Department'] = 'Sales'
    if job_role == 'human resourses':
        df.loc[index, 'Department'] = 'Human Resources'
    if job_role == 'research director'  or job_role == 'manufacturing director' or job_role == 'laboratory technician'or job_role == 'research scientist'or job_role == 'healthcare representative':
       df.loc[index, 'Department'] = 'Research & Development'


#Columna 'Distance_From_Home'
df['Distance_From_Home'] = df['Distance_From_Home'].str.replace('-', '')

#Columna 'Environment_Satisfaction'
#Creamos 4 grupos diferentes
for index, row in df.iterrows():
    numero = int(row['Environment_Satisfaction'])
    if numero < 10 and numero not in [2, 3, 4]:
        df.loc[index, 'Environment_Satisfaction'] = 1
    elif 10 <= numero <= 20:
        df.loc[index, 'Environment_Satisfaction'] = 2
    elif 20 < numero <= 30:
        df.loc[index, 'Environment_Satisfaction'] = 3
    elif 30 < numero <= 49:
        df.loc[index, 'Environment_Satisfaction'] = 4

#Columna 'Gender'        
df['Gender'] = df['Gender'].replace({'0': 'M', '1': 'F'})

#Columna 'Marital_Status'
df['Marital_Status']= df['Marital_Status'].replace({'Marreid':'Married'})

# %% [markdown]
# 1.4.6 Str a .title()

# %%
lista_col_to_title = ['Business_Travel', 'Education_Field','Job_Role','Marital_Status']

for col in lista_col_to_title:
    df[col] = df[col].str.title()

# %% [markdown]
# 1.4.7 Cambio de nulos str a 99999

# %%
lista_col_int_nulos=['Daily_Rate','Employee_Number','Hourly_Rate','Monthly_Income','Performance_Rating','Total_Working_Years','Work_Life_Balance']

for col in lista_col_int_nulos:
    df[col]=df[col].replace({'nan':99999,'NaN':99999, 'Not Available':99999})

# %% [markdown]
# ## 1.5 Cambio a formato deseado

# %% [markdown]
# 1.5.1 Cambio a int

# %%
lista_col_to_int=['Age','Daily_Rate','Distance_From_Home','Employee_Number','Environment_Satisfaction','Hourly_Rate','Job_Involvement','Monthly_Income','Monthly_Rate','Total_Working_Years','Performance_Rating','Work_Life_Balance']

for col in lista_col_to_int:
    df[col] = df[col].astype(int)

# %% [markdown]
# 1.5.2 Cambio a float

# %%
# lista_col_to_float=['Daily_Rate']

# for col in lista_col_to_float:
#     df[col] = df[col].astype(float)

# %% [markdown]
# 1.5.3 Cambio a Bool

# %%
lista_col_to_bool=['Remote_Work']

for col in lista_col_to_bool:
    df[col] = df[col].astype(bool)

# %%
# Comprobamos los dtypes del DF
df.dtypes
# Out:
# Age                            int64
# Age_Group                     object
# Attrition                       bool
# Business_Travel               object
# Daily_Rate                     int64
# Department                    object
# Distance_From_Home             int64
# Education                      int64
# Education_Field               object
# Employee_Number                int64
# Environment_Satisfaction       int64
# Gender                        object
# Hourly_Rate                    int64
# Job_Involvement                int64
# Job_Level                      int64
# Job_Role                      object
# Job_Satisfaction               int64
# Marital_Status                object
# Monthly_Income                 int64
# Monthly_Rate                   int64
# Num_Companies_Worked           int64
# Over_Time                     object
# Percent_Salary_Hike            int64
# Performance_Rating             int64
# Relationship_Satisfaction      int64
# Satisfaction_Group            object
# Stock_Option_Level             int64
# Total_Working_Years            int64
# Training_Times_Last_Year       int64
# Work_Life_Balance              int64
# Years_At_Company               int64
# Years_Since_Last_Promotion     int64
# Years_With_Curr_Manager        int64
# Date_Birth                     int64
# Remote_Work                     bool
# dtype: object

# %% [markdown]
# ## 1.6 Reemplazando nulos

# %% [markdown]
# 1.6.1 Int con .median()

# %%
lista_col_median = ['Performance_Rating','Work_Life_Balance']

for col in lista_col_median:
    df[col]=df[col].replace({99999:np.nan})
    df[col] = df[col].fillna(df[col].median()).astype(int)

# %% [markdown]
# 1.6.2 int con .mean()

# %%
lista_col_mean = ['Total_Working_Years']

for col in lista_col_mean:
    df[col]=df[col].replace({99999:np.nan})
    df[col] = df[col].fillna(df[col].mean()).astype(int)

# %% [markdown]
# 1.6.4 Categóricos a 'Unknown'

# %%
# creo la funcion
def reemplazar_nulos_por_unknown(df, columnas_nulos):
    for columna in columnas_nulos:
        df[columna] = df[columna].replace({'nan':None,'Nan':None})
        df[columna].fillna('Unknown', inplace=True)
    return df

# creo lista de columnas
lista_col_unknown =['Business_Travel','Department','Education_Field','Marital_Status','Over_Time']
    
df = reemplazar_nulos_por_unknown(df, lista_col_unknown)

# %% [markdown]
# ### 1.7 Rellenar columnas nuevas

# %%
#Columna 'Age_Group'
rangos_edad = ['18-25', '26-35', '36-45', '46-55', '56-65']
limites = [18, 26, 36, 46, 56, 66] # define los límites de cada grupo de edad, donde cada límite es exclusivo del grupo siguiente (excepto el último).

df['Age_Group'] = pd.cut(df['Age'], bins=limites, labels=rangos_edad, right=False)

# %%
df['Satisfaction_Group'].replace('nan',None, inplace=True)

# %% [markdown]
# ## Paso 2:Eliminamos duplicados

# %%
#Obtenemos el listado del nombre de las columnas del DF
lista_col_names = set(df.columns.tolist())
len(lista_col_names)
# Out:
# 35

# %%
#Obtenemos un df de los duplicados
df_duplicados = df[df['Employee_Number'].isin(df['Employee_Number'][df['Employee_Number'].duplicated()])].sort_values('Employee_Number')
df_duplicados
# Out:
#       Age Age_Group  Attrition Business_Travel  Daily_Rate  \
# 82     38     36-45      False         Unknown         119
# 1474   38     36-45      False         Unknown         119
# 1476   55     46-55      False   Travel Rarely         452
# 84     55     46-55      False   Travel Rarely         452
# 1542   47     46-55       True      Non Travel         666
# ...   ...       ...        ...             ...         ...
# 614    35     26-35      False   Travel Rarely         528
# 610    54     46-55      False         Unknown        1082
# 607    30     26-35      False   Travel Rarely         231
# 661    31     26-35      False      Non Travel       99999
# 1613   46     46-55      False         Unknown         566
#
#                   Department  Distance_From_Home  Education   Education_Field  \
# 82                     Sales                   3          3     Life Sciences
# 1474                   Sales                   3          3     Life Sciences
# 1476                 Unknown                   1          3           Medical
# 84                   Unknown                   1          3           Medical
# 1542                 Unknown                  29          4     Life Sciences
# ...                      ...                 ...        ...               ...
# 614                  Unknown                   8          4  Technical Degree
# 610                    Sales                   2          4     Life Sciences
# 607                    Sales                   8          2           Unknown
# 661   Research & Development                   5          3           Medical
# 1613  Research & Development                   7          2           Medical
#
#       Employee_Number  Environment_Satisfaction Gender  Hourly_Rate  \
# 82                307                         1      M           76
# 1474              307                         1      M           76
# 1476              374                         4      M           81
# 84                374                         4      M           81
# 1542              376                         1      M           88
# ...               ...                       ...    ...          ...
# 614             99999                         3      M          100
# 610             99999                         3      F           41
# 607             99999                         3      M           62
# 661             99999                         2      M           74
# 1613            99999                         4      M           75
#
#       Job_Involvement  Job_Level                  Job_Role  Job_Satisfaction  \
# 82                  3          3          Sales Executive                  3
# 1474                3          3          Sales Executive                  3
# 1476                3          5                  Manager                  1
# 84                  3          5                  Manager                  1
# 1542                3          3                  Manager                  2
# ...               ...        ...                       ...               ...
# 614                 3          1          Human Resources                  3
# 610                 2          3          Sales Executive                  3
# 607                 3          3          Sales Executive                  3
# 661                 3          2   Manufacturing Director                  1
# 1613                3          3   Manufacturing Director                  3
#
#      Marital_Status  Monthly_Income  Monthly_Rate  Num_Companies_Worked  \
# 82         Divorced           99999          9647                     0
# 1474       Divorced           99999          9647                     0
# 1476         Single           19045         18938                     0
# 84           Single           19045         18938                     0
# 1542        Married           99999         10268                     1
# ...             ...             ...           ...                   ...
# 614         Unknown            4323          7108                     1
# 610         Married           99999          8392                     6
# 607         Unknown           99999          9977                     5
# 661         Unknown            9936          3787                     0
# 1613        Unknown           10845         24208                     6
#
#      Over_Time  Percent_Salary_Hike  Performance_Rating  \
# 82     Unknown                   12                   3
# 1474   Unknown                   12                   3
# 1476   Unknown                   14                   3
# 84     Unknown                   14                   3
# 1542   Unknown                   12                   3
# ...        ...                  ...                 ...
# 614      False                   17                   3
# 610      False                   11                   3
# 607      False                   11                   3
# 661      False                   19                   3
# 1613   Unknown                   13                   3
#
#       Relationship_Satisfaction Satisfaction_Group  Stock_Option_Level  \
# 82                            3                                      2
# 1474                          3                                      2
# 1476                          3                                      0
# 84                            3                                      0
# 1542                          4                                      1
# ...                         ...                ...                 ...
# 614                           2                                      0
# 610                           2                                      1
# 607                           1                                      1
# 661                           2                                      0
# 1613                          2                                      1
#
#       Total_Working_Years  Training_Times_Last_Year  Work_Life_Balance  \
# 82                     11                         6                  2
# 1474                   11                         6                  2
# 1476                   37                         2                  3
# 84                     37                         2                  3
# 1542                   11                         2                  2
# ...                   ...                       ...                ...
# 614                     6                         2                  1
# 610                    13                         4                  3
# 607                    11                         2                  4
# 661                    10                         2                  3
# 1613                   11                         3                  3
#
#       Years_At_Company  Years_Since_Last_Promotion  Years_With_Curr_Manager  \
# 82                  16                           5                       13
# 1474                16                           5                       13
# 1476                36                           4                       13
# 84                  36                           4                       13
# 1542                10                           9                        9
# ...                ...                         ...                      ...
# 614                  5                           1                        4
# 610                  9                           7                        0
# 607                  8                           7                        7
# 661                  9                           1                        7
# 1613                 8                           0                        7
#
#       Date_Birth  Remote_Work
# 82          1985         True
# 1474        1985         True
# 1476        1968         True
# 84          1968         True
# 1542        1976        False
# ...          ...          ...
# 614         1988         True
# 610         1969         True
# 607         1993        False
# 661         1992         True
# 1613        1977        False
#
# [639 rows x 35 columns]

# %%
#Comprobamos cuantos duplicados tenemos en 'Employee_Number' 
df['Employee_Number'].duplicated().sum()
# Out:
# 534

# %%
#Comprobamos la cantidad que tenemos de 'Employee_Number'==99999
df[df['Employee_Number']==99999].shape[0]
# Out:
# 431

# %% [markdown]
# ### 2.1 Situación 1: Todas las columnas son iguales

# %%
#Comprobamos el número de duplicados en el DF
df.duplicated().sum()
# Out:
# 51

# %%
#Eliminamos los duplicados 
df.drop_duplicates(keep='last',inplace=True)

# %%
#Comprobamos el número de duplicados en el DF
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 2.2 Situación 2:Columna 'Distance_From_Home' diferente

# %%
#Creamos la lista con el subset de columnas a analizar
lista_columnas_2 = set(lista_col_names)
lista_columnas_2.remove('Distance_From_Home')
len(lista_columnas_2)
# Out:
# 34

# %% [markdown]
# ### Nota Patri: Cambio a lista porque me sigue dando error

# %%
lista_columnas_2 = list(lista_columnas_2)

# %%
#Comprobamos el numero de duplicados en el subset
df[lista_columnas_2].duplicated().sum()
# Out:
# 16

# %%
#Eliminamos los duplicados del subset
df.drop_duplicates(subset=lista_columnas_2, keep='last',inplace=True)

# %%
#Comprobamos el numero de duplicados en el subset
df[lista_columnas_2].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 2.3 Situación 3: Columnas 'Remote_Work' diferente

# %%
#Creamos la lista con el subset de columnas a analizar
lista_columnas_3 = set(lista_col_names)
lista_columnas_3.remove('Remote_Work')
len(lista_columnas_3)
# Out:
# 34

# %% [markdown]
# ### Cambio-Patri: CAmbio a lista me sigue dando error como set:

# %%
lista_columnas_3 = list(lista_columnas_3)

# %%
#Comprobamos el numero de duplicados en el subset
df[lista_columnas_3].duplicated().sum()
# Out:
# 48

# %%
#Eliminamos los duplicados del subset
df.drop_duplicates(subset=lista_columnas_3,keep='last',inplace=True)

# %%
#Comprobamos el numero de duplicados en el subset
df[lista_columnas_3].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 2.4 Situación 4: Columna 'Distance_From_Home' & 'Remote_Work' diferentes

# %%
#Creamos la lista con el subset de columnas a analizar
lista_columnas_4 = set(lista_col_names)
lista_columnas_4.remove('Distance_From_Home')
lista_columnas_4.remove('Remote_Work')
len(lista_columnas_4)
# Out:
# 33

# %% [markdown]
# ### Cambio Patri: Paso de set a lista para que no me error:

# %%
lista_columnas_4 = list(lista_columnas_4)

# %%
#Comprobamos el numero de duplicados en el subset
df[lista_columnas_4].duplicated().sum()
# Out:
# 6

# %%
#Eliminamos los duplicados del subset
df.drop_duplicates(subset=lista_columnas_4,keep='last',inplace=True)

# %%
#Comprobamos el numero de duplicados en el subset
df[lista_columnas_4].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 2.5 Situación 5: Columna 'Hourly_Rate' == 'Not_Available'

# %%
# Creamos un DF de duplicados nuevo
df_duplicados_s5 = df[df['Employee_Number'].isin(df['Employee_Number'][df['Employee_Number'].duplicated() ])].sort_values('Employee_Number')
df_duplicados_s5
# Out:
#       Age Age_Group  Attrition Business_Travel  Daily_Rate  \
# 871    31     26-35      False   Travel Rarely         691
# 1512   31     26-35      False   Travel Rarely         691
# 1515   52     46-55       True         Unknown         723
# 874    52     46-55       True         Unknown         723
# 1527   29     26-35      False         Unknown        1283
# ...   ...       ...        ...             ...         ...
# 562    35     26-35      False   Travel Rarely        1214
# 561    32     26-35      False   Travel Rarely         548
# 559    35     26-35      False   Travel Rarely         809
# 904    29     26-35       True         Unknown         408
# 1613   46     46-55      False         Unknown         566
#
#                   Department  Distance_From_Home  Education   Education_Field  \
# 871   Research & Development                  11          4           Unknown
# 1512  Research & Development                   5          4           Unknown
# 1515  Research & Development                   8          4           Medical
# 874   Research & Development                  17          4           Medical
# 1527  Research & Development                  23          3           Unknown
# ...                      ...                 ...        ...               ...
# 562   Research & Development                   1          3           Medical
# 561   Research & Development                   1          3     Life Sciences
# 559   Research & Development                  16          3           Medical
# 904   Research & Development                  25          5  Technical Degree
# 1613  Research & Development                   7          2           Medical
#
#       Employee_Number  Environment_Satisfaction Gender  Hourly_Rate  \
# 871               423                         2      M           86
# 1512              423                         3      M           86
# 1515              433                         3      M           85
# 874               433                         2      M           85
# 1527              495                         4      M           54
# ...               ...                       ...    ...          ...
# 562             99999                         2      M           30
# 561             99999                         2      M           66
# 559             99999                         1      M           84
# 904             99999                         3      F           71
# 1613            99999                         4      M           75
#
#       Job_Involvement  Job_Level                  Job_Role  Job_Satisfaction  \
# 871                 3          1       Research Scientist                  4
# 1512                3          1       Research Scientist                  4
# 1515                2          2       Research Scientist                  2
# 874                 2          2       Research Scientist                  2
# 1527                3          1       Research Scientist                  4
# ...               ...        ...                       ...               ...
# 562                 2          1       Research Scientist                  3
# 561                 3          2       Research Scientist                  2
# 559                 4          1    Laboratory Technician                  2
# 904                 2          1       Research Scientist                  2
# 1613                3          3   Manufacturing Director                  3
#
#      Marital_Status  Monthly_Income  Monthly_Rate  Num_Companies_Worked  \
# 871         Married           99999         10077                     0
# 1512        Married           99999         10077                     0
# 1515        Unknown            4941         17747                     2
# 874         Unknown            4941         17747                     2
# 1527        Unknown           99999         18168                     9
# ...             ...             ...           ...                   ...
# 562          Single           99999         26278                     1
# 561         Unknown           99999          7346                     1
# 559         Married           99999         16479                     0
# 904         Married            2546         18300                     5
# 1613        Unknown           10845         24208                     6
#
#      Over_Time  Percent_Salary_Hike  Performance_Rating  \
# 871    Unknown                   12                   3
# 1512   Unknown                   12                   3
# 1515     False                   15                   3
# 874      False                   15                   3
# 1527     False                   16                   3
# ...        ...                  ...                 ...
# 562      False                   18                   3
# 561      False                   17                   3
# 559    Unknown                   13                   3
# 904      False                   16                   3
# 1613   Unknown                   13                   3
#
#       Relationship_Satisfaction Satisfaction_Group  Stock_Option_Level  \
# 871                           3                                      1
# 1512                          3                                      1
# 1515                          1                                      0
# 874                           1                                      0
# 1527                          4                                      0
# ...                         ...                ...                 ...
# 562                           1                                      0
# 561                           2                                      2
# 559                           3                                      1
# 904                           2                                      0
# 1613                          2                                      1
#
#       Total_Working_Years  Training_Times_Last_Year  Work_Life_Balance  \
# 871                    11                         4                  3
# 1512                   11                         4                  3
# 1515                   11                         3                  2
# 874                    11                         3                  2
# 1527                    6                         4                  3
# ...                   ...                       ...                ...
# 562                     6                         3                  3
# 561                    10                         3                  3
# 559                     6                         5                  3
# 904                     6                         2                  4
# 1613                   11                         3                  3
#
#       Years_At_Company  Years_Since_Last_Promotion  Years_With_Curr_Manager  \
# 871                  5                           0                        3
# 1512                 5                           0                        3
# 1515                 8                           7                        7
# 874                  8                           7                        7
# 1527                 3                           1                        2
# ...                ...                         ...                      ...
# 562                  6                           0                        4
# 561                 10                           0                        9
# 559                  5                           0                        3
# 904                  2                           1                        1
# 1613                 8                           0                        7
#
#       Date_Birth  Remote_Work
# 871         1992         True
# 1512        1992         True
# 1515        1971        False
# 874         1971        False
# 1527        1994         True
# ...          ...          ...
# 562         1988        False
# 561         1991         True
# 559         1988        False
# 904         1994        False
# 1613        1977        False
#
# [430 rows x 35 columns]

# %%
# Filrtamos el DF para obtener el DF dónde el 'Hourly_Rate'==99999 y el 'Employee_Number' != 999999
df_duplicados_s5_filtrado = df_duplicados_s5[df_duplicados_s5['Hourly_Rate']==99999]
df_duplicados_s5_filtrado = df_duplicados_s5_filtrado.loc[df_duplicados_s5_filtrado['Employee_Number']!=99999,:]
df_duplicados_s5_filtrado
# Out:
#       Age Age_Group  Attrition    Business_Travel  Daily_Rate  \
# 892    42     36-45      False            Unknown         201
# 1566   35     26-35      False      Travel Rarely        1276
# 1578   29     26-35      False            Unknown         806
# 340    27     26-35      False      Travel Rarely       99999
# 1604   41     36-45       True            Unknown        1085
# 1605   31     26-35      False      Travel Rarely         154
# 987    33     26-35      False         Non Travel        1038
# 1008   35     26-35      False  Travel Frequently       99999
#
#                   Department  Distance_From_Home  Education Education_Field  \
# 892   Research & Development                   1          4         Unknown
# 1566  Research & Development                  16          3   Life Sciences
# 1578  Research & Development                   1          4   Life Sciences
# 340   Research & Development                   1          2   Life Sciences
# 1604  Research & Development                   2          4   Life Sciences
# 1605                 Unknown                   7          4         Unknown
# 987                    Sales                   8          1   Life Sciences
# 1008  Research & Development                   4          4           Other
#
#       Employee_Number  Environment_Satisfaction Gender  Hourly_Rate  \
# 892               517                         2      F        99999
# 1566              586                         4      M        99999
# 1578              710                         2      M        99999
# 340               725                         3      F        99999
# 1604              927                         2      F        99999
# 1605              941                         2      M        99999
# 987              1044                         2      F        99999
# 1008             1185                         4      M        99999
#
#       Job_Involvement  Job_Level                     Job_Role  \
# 892                 3          1       Laboratory Technician
# 1566                3          3   Healthcare Representative
# 1578                1          1          Research Scientist
# 340                 3          3      Manufacturing Director
# 1604                1          1       Laboratory Technician
# 1605                2          1        Sales Representative
# 987                 2          1        Sales Representative
# 1008                2          1       Laboratory Technician
#
#       Job_Satisfaction Marital_Status  Monthly_Income  Monthly_Rate  \
# 892                  1        Unknown           99999         20490
# 1566                 3        Unknown           99999         14295
# 1578                 4       Divorced           99999         18959
# 340                  1        Married           99999          6009
# 1604                 4       Divorced           99999         17725
# 1605                 3        Unknown            2329         11737
# 987                  4        Unknown           99999         21437
# 1008                 4        Married            2376         26537
#
#       Num_Companies_Worked Over_Time  Percent_Salary_Hike  Performance_Rating  \
# 892                      3     False                   16                   3
# 1566                     4      True                   12                   3
# 1578                     1   Unknown                   18                   3
# 340                      1   Unknown                   11                   3
# 1604                     4      True                   13                   3
# 1605                     3   Unknown                   15                   3
# 987                      0   Unknown                   19                   3
# 1008                     1   Unknown                   13                   3
#
#       Relationship_Satisfaction Satisfaction_Group  Stock_Option_Level  \
# 892                           2                                      1
# 1566                          3                                      0
# 1578                          4                                      1
# 340                           4                                      0
# 1604                          3                                      1
# 1605                          2                                      0
# 987                           4                                      0
# 1008                          2                                      1
#
#       Total_Working_Years  Training_Times_Last_Year  Work_Life_Balance  \
# 892                     8                         5                  3
# 1566                   10                         2                  3
# 1578                   10                         5                  3
# 340                     9                         3                  3
# 1604                   11                         1                  2
# 1605                   11                         2                  4
# 987                    11                         2                  2
# 1008                    2                         2                  4
#
#       Years_At_Company  Years_Since_Last_Promotion  Years_With_Curr_Manager  \
# 892                  5                           1                        2
# 1566                 8                           0                        0
# 1578                10                           2                        8
# 340                  9                           0                        7
# 1604                 7                           1                        0
# 1605                 7                           5                        2
# 987                  2                           2                        2
# 1008                 2                           2                        2
#
#       Date_Birth  Remote_Work
# 892         1981         True
# 1566        1988         True
# 1578        1994         True
# 340         1996        False
# 1604        1982         True
# 1605        1992         True
# 987         1990        False
# 1008        1988         True

# %%
#Guardamos en una lista los números de los índices de todas las filas del DF filtrado 'df_duplicados_s5_filtrado'
lista_index_situacion_5= df_duplicados_s5_filtrado.index.tolist()

# %%
#Utilizamos un for loop para iterar por la lista de los números de índice y eliminamos cada uno de estos de nuestro DF original
for employee in lista_index_situacion_5:
    df.drop(employee,axis=0,inplace=True)

# %%
df['Employee_Number'].duplicated().sum()
# Out:
# 405

# %% [markdown]
# ### 2.6 Situación 6: Columna 'Distance_From_Home' == 'Environment_Satisfaction'

# %%
# Creamos un DF de duplicados nuevo
df_duplicados_s6 = df[df['Employee_Number'].isin(df['Employee_Number'][df['Employee_Number'].duplicated() ])].sort_values('Employee_Number')
df_duplicados_s6
# Out:
#       Age Age_Group  Attrition Business_Travel  Daily_Rate  \
# 871    31     26-35      False   Travel Rarely         691
# 1512   31     26-35      False   Travel Rarely         691
# 1515   52     46-55       True         Unknown         723
# 874    52     46-55       True         Unknown         723
# 886    29     26-35      False         Unknown        1283
# ...   ...       ...        ...             ...         ...
# 559    35     26-35      False   Travel Rarely         809
# 558    41     36-45       True         Unknown        1102
# 557    47     46-55       True         Unknown        1093
# 591    52     46-55      False   Travel Rarely         319
# 1613   46     46-55      False         Unknown         566
#
#                   Department  Distance_From_Home  Education Education_Field  \
# 871   Research & Development                  11          4         Unknown
# 1512  Research & Development                   5          4         Unknown
# 1515  Research & Development                   8          4         Medical
# 874   Research & Development                  17          4         Medical
# 886   Research & Development                  17          3         Unknown
# ...                      ...                 ...        ...             ...
# 559   Research & Development                  16          3         Medical
# 558                    Sales                   1          2         Unknown
# 557                    Sales                   9          3         Unknown
# 591   Research & Development                  32          3         Unknown
# 1613  Research & Development                   7          2         Medical
#
#       Employee_Number  Environment_Satisfaction Gender  Hourly_Rate  \
# 871               423                         2      M           86
# 1512              423                         3      M           86
# 1515              433                         3      M           85
# 874               433                         2      M           85
# 886               495                         2      M           54
# ...               ...                       ...    ...          ...
# 559             99999                         1      M           84
# 558             99999                         2      F           94
# 557             99999                         3      M           82
# 591             99999                         4      M        99999
# 1613            99999                         4      M           75
#
#       Job_Involvement  Job_Level                  Job_Role  Job_Satisfaction  \
# 871                 3          1       Research Scientist                  4
# 1512                3          1       Research Scientist                  4
# 1515                2          2       Research Scientist                  2
# 874                 2          2       Research Scientist                  2
# 886                 3          1       Research Scientist                  4
# ...               ...        ...                       ...               ...
# 559                 4          1    Laboratory Technician                  2
# 558                 3          2          Sales Executive                  4
# 557                 1          4          Sales Executive                  3
# 591                 2          3   Manufacturing Director                  3
# 1613                3          3   Manufacturing Director                  3
#
#      Marital_Status  Monthly_Income  Monthly_Rate  Num_Companies_Worked  \
# 871         Married           99999         10077                     0
# 1512        Married           99999         10077                     0
# 1515        Unknown            4941         17747                     2
# 874         Unknown            4941         17747                     2
# 886         Unknown           99999         18168                     9
# ...             ...             ...           ...                   ...
# 559         Married           99999         16479                     0
# 558         Unknown           99999         19479                     8
# 557         Married           12936         24164                     7
# 591         Married           99999         19609                     2
# 1613        Unknown           10845         24208                     6
#
#      Over_Time  Percent_Salary_Hike  Performance_Rating  \
# 871    Unknown                   12                   3
# 1512   Unknown                   12                   3
# 1515     False                   15                   3
# 874      False                   15                   3
# 886      False                   16                   3
# ...        ...                  ...                 ...
# 559    Unknown                   13                   3
# 558       True                   11                   3
# 557      False                   11                   3
# 591    Unknown                   14                   3
# 1613   Unknown                   13                   3
#
#       Relationship_Satisfaction Satisfaction_Group  Stock_Option_Level  \
# 871                           3                                      1
# 1512                          3                                      1
# 1515                          1                                      0
# 874                           1                                      0
# 886                           4                                      0
# ...                         ...                ...                 ...
# 559                           3                                      1
# 558                           1                                      0
# 557                           3                                      0
# 591                           3                                      0
# 1613                          2                                      1
#
#       Total_Working_Years  Training_Times_Last_Year  Work_Life_Balance  \
# 871                    11                         4                  3
# 1512                   11                         4                  3
# 1515                   11                         3                  2
# 874                    11                         3                  2
# 886                     6                         4                  3
# ...                   ...                       ...                ...
# 559                     6                         5                  3
# 558                     8                         0                  1
# 557                    25                         3                  1
# 591                    11                         4                  3
# 1613                   11                         3                  3
#
#       Years_At_Company  Years_Since_Last_Promotion  Years_With_Curr_Manager  \
# 871                  5                           0                        3
# 1512                 5                           0                        3
# 1515                 8                           7                        7
# 874                  8                           7                        7
# 886                  3                           1                        2
# ...                ...                         ...                      ...
# 559                  5                           0                        3
# 558                  6                           0                        5
# 557                 23                          14                       10
# 591                  5                           0                        4
# 1613                 8                           0                        7
#
#       Date_Birth  Remote_Work
# 871         1992         True
# 1512        1992         True
# 1515        1971        False
# 874         1971        False
# 886         1994        False
# ...          ...          ...
# 559         1988        False
# 558         1982        False
# 557         1976         True
# 591         1971        False
# 1613        1977        False
#
# [414 rows x 35 columns]

# %%
# Filtramos el DF para obtener el DF dónde el 'Distance_From_Home' == 'Environment_Satisfaction'
# y el 'Employee_Number' != 999999
df_duplicados_s6_filtrado = df_duplicados_s6[(df_duplicados_s6['Distance_From_Home']==df_duplicados_s6['Environment_Satisfaction'])]
df_duplicados_s6_filtrado = df_duplicados_s6_filtrado.loc[df_duplicados_s6_filtrado['Employee_Number']!=99999,:]
df_duplicados_s6_filtrado
# Out:
# Empty DataFrame
# Columns: [Age, Age_Group, Attrition, Business_Travel, Daily_Rate, Department, Distance_From_Home, Education, Education_Field, Employee_Number, Environment_Satisfaction, Gender, Hourly_Rate, Job_Involvement, Job_Level, Job_Role, Job_Satisfaction, Marital_Status, Monthly_Income, Monthly_Rate, Num_Companies_Worked, Over_Time, Percent_Salary_Hike, Performance_Rating, Relationship_Satisfaction, Satisfaction_Group, Stock_Option_Level, Total_Working_Years, Training_Times_Last_Year, Work_Life_Balance, Years_At_Company, Years_Since_Last_Promotion, Years_With_Curr_Manager, Date_Birth, Remote_Work]
# Index: []

# %%
# Guardamos en una lista los números de los índices de todas las filas del DF filtrado 'df_duplicados_s6_filtrado'
lista_index_situacion_6=df_duplicados_s6_filtrado.index.tolist()

# %%
#Utilizamos un for loop para iterar por la lista de los números de índice y eliminamos cada uno de estos de nuestro DF original
for employee in lista_index_situacion_6:
    df.drop(employee,axis=0,inplace=True)

# %% [markdown]
# ## Paso 3: Cambio 'Employee_Number' Nulos

# %%
# Mostramos del DF original los 'Employee_number' == 99999
df[df['Employee_Number']==99999]
# Out:
#       Age Age_Group  Attrition Business_Travel  Daily_Rate  \
# 3      47     46-55      False   Travel Rarely         359
# 4      46     46-55      False         Unknown        1319
# 8      41     36-45      False         Unknown        1276
# 11     56     56-65      False   Travel Rarely        1369
# 12     38     36-45      False         Unknown         201
# ...   ...       ...        ...             ...         ...
# 1601   28     26-35      False         Unknown         760
# 1602   26     26-35       True         Unknown       99999
# 1607   31     26-35      False         Unknown         616
# 1611   39     36-45      False   Travel Rarely         903
# 1613   46     46-55      False         Unknown         566
#
#                   Department  Distance_From_Home  Education   Education_Field  \
# 3     Research & Development                   2          4           Medical
# 4                      Sales                   3          3  Technical Degree
# 8                    Unknown                   2          5           Unknown
# 11    Research & Development                  23          3     Life Sciences
# 12    Research & Development                  10          3           Medical
# ...                      ...                 ...        ...               ...
# 1601                   Sales                  43          4           Unknown
# 1602  Research & Development                   5          2           Medical
# 1607  Research & Development                  12          3           Medical
# 1611                   Sales                  13          5           Unknown
# 1613  Research & Development                   7          2           Medical
#
#       Employee_Number  Environment_Satisfaction Gender  Hourly_Rate  \
# 3               99999                         1      F           82
# 4               99999                         1      F           45
# 8               99999                         2      F           91
# 11              99999                         4      M           68
# 12              99999                         2      F           99
# ...               ...                       ...    ...          ...
# 1601            99999                         4      F           81
# 1602            99999                         3      F           88
# 1607            99999                         4      F           41
# 1611            99999                         2      M           41
# 1613            99999                         4      M           75
#
#       Job_Involvement  Job_Level                     Job_Role  \
# 3                   3          4           Research Director
# 4                   4          4             Sales Executive
# 8                   3          4                     Manager
# 11                  3          4      Manufacturing Director
# 12                  1          3           Research Director
# ...               ...        ...                          ...
# 1601                3          2             Sales Executive
# 1602                2          1          Research Scientist
# 1607                3          2   Healthcare Representative
# 1611                4          3             Sales Executive
# 1613                3          3      Manufacturing Director
#
#       Job_Satisfaction Marital_Status  Monthly_Income  Monthly_Rate  \
# 3                    3        Married           17169         26703
# 4                    1       Divorced           99999          7739
# 8                    1        Married           16595          5626
# 11                   2        Married           13402         18235
# 12                   3        Married           13206          3376
# ...                ...            ...             ...           ...
# 1601                 2        Unknown           99999          3698
# 1602                 3        Married            2366         20898
# 1607                 4        Unknown           99999         17369
# 1611                 3         Single           99999          2560
# 1613                 3        Unknown           10845         24208
#
#       Num_Companies_Worked Over_Time  Percent_Salary_Hike  Performance_Rating  \
# 3                        3   Unknown                   19                   3
# 4                        2     False                   12                   3
# 8                        7     False                   16                   3
# 11                       4      True                   12                   3
# 12                       3     False                   12                   3
# ...                    ...       ...                  ...                 ...
# 1601                     1   Unknown                   20                   4
# 1602                     1   Unknown                   14                   3
# 1607                     0   Unknown                   11                   3
# 1611                     0     False                   18                   3
# 1613                     6   Unknown                   13                   3
#
#       Relationship_Satisfaction Satisfaction_Group  Stock_Option_Level  \
# 3                             2                                      2
# 4                             4                                      1
# 8                             2                                      1
# 11                            1                                      1
# 12                            1                                      1
# ...                         ...                ...                 ...
# 1601                          1                                      0
# 1602                          1                                      1
# 1607                          3                                      2
# 1611                          4                                      0
# 1613                          2                                      1
#
#       Total_Working_Years  Training_Times_Last_Year  Work_Life_Balance  \
# 3                      11                         2                  3
# 4                      11                         5                  3
# 8                      22                         2                  3
# 11                     33                         0                  3
# 12                     11                         3                  3
# ...                   ...                       ...                ...
# 1601                    8                         2                  3
# 1602                    8                         2                  3
# 1607                   10                         2                  1
# 1611                    9                         3                  3
# 1613                   11                         3                  3
#
#       Years_At_Company  Years_Since_Last_Promotion  Years_With_Curr_Manager  \
# 3                   20                           5                        6
# 4                   19                           2                        8
# 8                   18                          11                        8
# 11                  19                          15                        9
# 12                  18                           1                       11
# ...                ...                         ...                      ...
# 1601                 8                           7                        5
# 1602                 8                           1                        7
# 1607                 9                           8                        5
# 1611                 8                           0                        7
# 1613                 8                           0                        7
#
#       Date_Birth  Remote_Work
# 3           1976        False
# 4           1977        False
# 8           1982         True
# 11          1967        False
# 12          1985         True
# ...          ...          ...
# 1601        1995        False
# 1602        1997         True
# 1607        1992         True
# 1611        1984         True
# 1613        1977        False
#
# [398 rows x 35 columns]

# %%
# Obtenemos una lista de los todos los 'Employee_Number' y la ordenamos de manera ascendente
lista_employee_number = df['Employee_Number'].unique().tolist()
lista_employee_number.sort()

# %%
# Obtenemos el número del último 'Employee_Number' sin tener en cuenta el 99999
lista_employee_number.remove(99999)
last_employee_number = lista_employee_number[-1]
last_employee_number
# Out:
# 2068

# %%
# Creamos la variable del primer nuevo número de 'Employee_Number' y
# del número de los índices de los 'Employee_Number' == 99999
new_employee_number = last_employee_number + 1
indices = df.index[df['Employee_Number'] == 99999]

#Iteramos con un for loop por la lista de índices y cambiamos el valor del 'Employee_Number' por el nuevo valor
for i in indices:
    df.loc[i, 'Employee_Number'] = new_employee_number
    new_employee_number += 1

# %%
#Comprobamos el tamaño final del DF
df.shape
# Out:
# (1485, 35)

# %%
#Comprobamos si quedan duplicados en la columna de 'Employee_Number'
df['Employee_Number'].duplicated().sum()
# Out:
# 8

# %%
#Adjudicamos la columna 'Employee_Number' cómo la columna de ínidce y eliminamos el actual índice
df.set_index('Employee_Number',drop=True,inplace=True)

# %%
#Visualizamos el DF resultante
df.head(5)
# Out:
#                  Age Age_Group  Attrition Business_Travel  Daily_Rate  \
# Employee_Number
# 162               51     46-55      False         Unknown         684
# 259               52     46-55      False         Unknown         699
# 319               42     36-45      False   Travel Rarely         532
# 2069              47     46-55      False   Travel Rarely         359
# 2070              46     46-55      False         Unknown        1319
#
#                              Department  Distance_From_Home  Education  \
# Employee_Number
# 162              Research & Development                   6          3
# 259                             Unknown                   1          4
# 319              Research & Development                   4          2
# 2069             Research & Development                   2          4
# 2070                              Sales                   3          3
#
#                   Education_Field  Environment_Satisfaction Gender  \
# Employee_Number
# 162                       Unknown                         1      M
# 259                 Life Sciences                         3      M
# 319              Technical Degree                         3      M
# 2069                      Medical                         1      F
# 2070             Technical Degree                         1      F
#
#                  Hourly_Rate  Job_Involvement  Job_Level             Job_Role  \
# Employee_Number
# 162                       51                3          5   Research Director
# 259                       65                2          5             Manager
# 319                       58                3          5             Manager
# 2069                      82                3          4   Research Director
# 2070                      45                4          4     Sales Executive
#
#                  Job_Satisfaction Marital_Status  Monthly_Income  \
# Employee_Number
# 162                             3        Unknown           19537
# 259                             3        Unknown           19999
# 319                             4        Married           19232
# 2069                            3        Married           17169
# 2070                            1       Divorced           99999
#
#                  Monthly_Rate  Num_Companies_Worked Over_Time  \
# Employee_Number
# 162                      6462                     7     False
# 259                      5678                     0   Unknown
# 319                      4933                     1     False
# 2069                    26703                     3   Unknown
# 2070                     7739                     2     False
#
#                  Percent_Salary_Hike  Performance_Rating  \
# Employee_Number
# 162                               13                   3
# 259                               14                   3
# 319                               11                   3
# 2069                              19                   3
# 2070                              12                   3
#
#                  Relationship_Satisfaction Satisfaction_Group  \
# Employee_Number
# 162                                      3
# 259                                      1
# 319                                      4
# 2069                                     2
# 2070                                     4
#
#                  Stock_Option_Level  Total_Working_Years  \
# Employee_Number
# 162                               0                   11
# 259                               1                   34
# 319                               0                   22
# 2069                              2                   11
# 2070                              1                   11
#
#                  Training_Times_Last_Year  Work_Life_Balance  \
# Employee_Number
# 162                                     5                  3
# 259                                     5                  3
# 319                                     3                  3
# 2069                                    2                  3
# 2070                                    5                  3
#
#                  Years_At_Company  Years_Since_Last_Promotion  \
# Employee_Number
# 162                            20                          15
# 259                            33                          11
# 319                            22                          11
# 2069                           20                           5
# 2070                           19                           2
#
#                  Years_With_Curr_Manager  Date_Birth  Remote_Work
# Employee_Number
# 162                                   15        1972         True
# 259                                    9        1971         True
# 319                                   15        1981         True
# 2069                                   6        1976        False
# 2070                                   8        1977        False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1485 entries, 162 to 2466
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         1485 non-null   int64
#  1   Age_Group                   1485 non-null   category
#  2   Attrition                   1485 non-null   bool
#  3   Business_Travel             1485 non-null   object
#  4   Daily_Rate                  1485 non-null   int64
#  5   Department                  1485 non-null   object
#  6   Distance_From_Home          1485 non-null   int64
#  7   Education                   1485 non-null   int64
#  8   Education_Field             1485 non-null   object
#  9   Environment_Satisfaction    1485 non-null   int64
#  10  Gender                      1485 non-null   object
#  11  Hourly_Rate                 1485 non-null   int64
#  12  Job_Involvement             1485 non-null   int64
#  13  Job_Level                   1485 non-null   int64
#  14  Job_Role                    1485 non-null   object
#  15  Job_Satisfaction            1485 non-null   int64
#  16  Marital_Status              1485 non-null   object
#  17  Monthly_Income              1485 non-null   int64
#  18  Monthly_Rate                1485 non-null   int64
#  19  Num_Companies_Worked        1485 non-null   int64
#  20  Over_Time                   1485 non-null   object
#  21  Percent_Salary_Hike         1485 non-null   int64
#  22  Performance_Rating          1485 non-null   int64
#  23  Relationship_Satisfaction   1485 non-null   int64
#  24  Satisfaction_Group          1485 non-null   object
#  25  Stock_Option_Level          1485 non-null   int64
#  26  Total_Working_Years         1485 non-null   int64
#  27  Training_Times_Last_Year    1485 non-null   int64
#  28  Work_Life_Balance           1485 non-null   int64
#  29  Years_At_Company            1485 non-null   int64
#  30  Years_Since_Last_Promotion  1485 non-null   int64
#  31  Years_With_Curr_Manager     1485 non-null   int64
#  32  Date_Birth                  1485 non-null   int64
#  33  Remote_Work                 1485 non-null   bool
# dtypes: bool(2), category(1), int64(23), object(8)
# memory usage: 375.8+ KB

# %%
df.describe().T
# Out:
#                              count          mean           std     min  \
# Age                         1485.0     36.942761      9.134814    18.0
# Daily_Rate                  1485.0   8287.696296  26205.342012   103.0
# Distance_From_Home          1485.0     11.299663     10.527645     1.0
# Education                   1485.0      2.916498      1.025170     1.0
# Environment_Satisfaction    1485.0      2.740741      1.089395     1.0
# Hourly_Rate                 1485.0   5180.501684  22028.799079    30.0
# Job_Involvement             1485.0      2.730640      0.711977     1.0
# Job_Level                   1485.0      2.065993      1.105467     1.0
# Job_Satisfaction            1485.0      2.729966      1.100330     1.0
# Monthly_Income              1485.0  55936.149495  46794.415899  1009.0
# Monthly_Rate                1485.0  14296.219529   7129.464478  2094.0
# Num_Companies_Worked        1485.0      2.701010      2.507569     0.0
# Percent_Salary_Hike         1485.0     15.216835      3.667459    11.0
# Performance_Rating          1485.0      3.136700      0.343646     3.0
# Relationship_Satisfaction   1485.0      2.712458      1.081023     1.0
# Stock_Option_Level          1485.0      0.791919      0.850203     0.0
# Total_Working_Years         1485.0     11.186532      6.337718     0.0
# Training_Times_Last_Year    1485.0      2.801347      1.286043     0.0
# Work_Life_Balance           1485.0      2.772391      0.684379     1.0
# Years_At_Company            1485.0      7.035690      6.136976     0.0
# Years_Since_Last_Promotion  1485.0      2.200000      3.234709     0.0
# Years_With_Curr_Manager     1485.0      4.143434      3.561781     0.0
# Date_Birth                  1485.0   1986.053872      9.133913  1963.0
#
#                                25%      50%      75%      max
# Age                           30.0     36.0     43.0     60.0
# Daily_Rate                   505.0    857.0   1238.0  99999.0
# Distance_From_Home             2.0      8.0     17.0     49.0
# Education                      2.0      3.0      4.0      5.0
# Environment_Satisfaction       2.0      3.0      4.0      4.0
# Hourly_Rate                   50.0     68.0     86.0  99999.0
# Job_Involvement                2.0      3.0      3.0      4.0
# Job_Level                      1.0      2.0      3.0      5.0
# Job_Satisfaction               2.0      3.0      4.0      4.0
# Monthly_Income              5070.0  99999.0  99999.0  99999.0
# Monthly_Rate                8040.0  14229.0  20460.0  26999.0
# Num_Companies_Worked           1.0      2.0      4.0      9.0
# Percent_Salary_Hike           12.0     14.0     18.0     25.0
# Performance_Rating             3.0      3.0      3.0      4.0
# Relationship_Satisfaction      2.0      3.0      4.0      4.0
# Stock_Option_Level             0.0      1.0      1.0      3.0
# Total_Working_Years            8.0     11.0     11.0     40.0
# Training_Times_Last_Year       2.0      3.0      3.0      6.0
# Work_Life_Balance              2.0      3.0      3.0      4.0
# Years_At_Company               3.0      5.0      9.0     40.0
# Years_Since_Last_Promotion     0.0      1.0      3.0     15.0
# Years_With_Curr_Manager        2.0      3.0      7.0     17.0
# Date_Birth                  1980.0   1987.0   1993.0   2005.0

# %%
df.columns
# Out:
# Index(['Age', 'Age_Group', 'Attrition', 'Business_Travel', 'Daily_Rate',
#        'Department', 'Distance_From_Home', 'Education', 'Education_Field',
#        'Environment_Satisfaction', 'Gender', 'Hourly_Rate', 'Job_Involvement',
#        'Job_Level', 'Job_Role', 'Job_Satisfaction', 'Marital_Status',
#        'Monthly_Income', 'Monthly_Rate', 'Num_Companies_Worked', 'Over_Time',
#        'Percent_Salary_Hike', 'Performance_Rating',
#        'Relationship_Satisfaction', 'Satisfaction_Group', 'Stock_Option_Level',
#        'Total_Working_Years', 'Training_Times_Last_Year', 'Work_Life_Balance',
#        'Years_At_Company', 'Years_Since_Last_Promotion',
#        'Years_With_Curr_Manager', 'Date_Birth', 'Remote_Work'],
#       dtype='object')

# %%
df.describe(include=['object','category','bool']).T
# Out:
#                    count unique                     top  freq
# Age_Group           1485      5                   26-35   613
# Attrition           1485      2                   False  1246
# Business_Travel     1485      4                 Unknown   713
# Department          1485      4  Research & Development   929
# Education_Field     1485      7                 Unknown   692
# Gender              1485      2                       M   891
# Job_Role            1485      9        Sales Executive    331
# Marital_Status      1485      4                 Unknown   597
# Over_Time           1485      3                   False   631
# Satisfaction_Group  1485      1                          1485
# Remote_Work         1485      2                    True   917

# %% [markdown]
# #### Cambio Patri:

# %%
nan_columns = df.columns[df.isna().any()].tolist()
print("Columnas con 'nan' :", nan_columns)
# Out:
# Columnas con 'nan' : []

# %%
df.to_csv('HR_CLEAN_DATA_2.csv',index=False)

# %%
#Guardamos el DF en formato .csv
# url_clean_data='https://raw.githubusercontent.com/nuriancg/project-da-promo-H-module-3-team-1/master/HR_CLEAN_DATA.csv'
# df.to_csv(url_clean_data, index=False)

# %% [markdown]
# # Bucle for para rellenar
# for index, row in df_raw_data.iterrows():
#     job_role = row['Job_Role'].strip().lower()
#     if job_role == 'sales executive':
#         df_raw_data.loc[index, 'Department'] = 'Sales'
#     if job_role == 'Human resourses':
#         df_raw_data.loc[index, 'Department'] = 'Human Resources'
#     if job_role == 'research director'  or job_role == 'manufacturing director' or job_role == 'laboratory technician'or job_role == 'research scientist'or job_role == 'healthcare representative':
#        df_raw_data.loc[index, 'Department'] = 'Research & Development'
