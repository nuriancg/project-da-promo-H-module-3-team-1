# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df_raw_data= pd.read_csv('HR_RAW_DATA.csv', index_col=0)

# %%
df_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1614 non-null   object
#  1   Attrition                 1614 non-null   object
#  2   BusinessTravel            842 non-null    object
#  3   DailyRate                 1614 non-null   object
#  4   Department                302 non-null    object
#  5   DistanceFromHome          1614 non-null   int64
#  6   Education                 1614 non-null   int64
#  7   EducationField            869 non-null    object
#  8   employeecount             1614 non-null   int64
#  9   employeenumber            1183 non-null   object
#  10  EnvironmentSatisfaction   1614 non-null   int64
#  11  Gender                    1614 non-null   int64
#  12  HourlyRate                1614 non-null   object
#  13  JobInvolvement            1614 non-null   int64
# ...

# %%
df_raw_data.head(10)
# Out:
#   Age Attrition     BusinessTravel DailyRate                Department  \
# 0  51        No                NaN    684,0$                       NaN
# 1  52        No                NaN    699,0$                       NaN
# 2  42        No      travel_rarely    532,0$   Research & Development
# 3  47        No      travel_rarely    359,0$                       NaN
# 4  46        No                NaN   1319,0$                       NaN
# 5  48        No                NaN    117,0$   Research & Development
# 6  59        No                NaN   1435,0$                       NaN
# 7  42        No      travel_rarely    635,0$                       NaN
# 8  41        No                NaN   1276,0$                       NaN
# 9  41        No  travel_frequently    840,0$                       NaN
#
#    DistanceFromHome  Education    EducationField  employeecount  \
# 0                 6          3               NaN              1
# ...

# %%
df_raw_data.tail(10)
# Out:
#      Age Attrition     BusinessTravel DailyRate                Department  \
# 1604  41       Yes                NaN   1085,0$   Research & Development
# 1605  31        No      travel_rarely    154,0$                       NaN
# 1606  26        No  travel_frequently   1283,0$                    Sales
# 1607  31        No                NaN    616,0$                       NaN
# 1608  32        No                NaN    498,0$                       NaN
# 1609  36       Yes      travel_rarely    530,0$                       NaN
# 1610  45        No         non-travel    805,0$                       NaN
# 1611  39        No      travel_rarely    903,0$                       NaN
# 1612  36        No         non-travel   1229,0$                       NaN
# 1613  46        No                NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# 1604                 2          4     Life Sciences              1
# ...

# %%
df_raw_data.sample(10)
# Out:
#      Age Attrition     BusinessTravel DailyRate                Department  \
# 268   42        No                NaN      nan$                       NaN
# 521   49        No                NaN   1023,0$                    Sales
# 337   39        No                NaN    408,0$                       NaN
# 1403  28        No      travel_rarely   1423,0$                       NaN
# 1095  36        No                NaN    711,0$                       NaN
# 296   38        No         non-travel   1327,0$                    Sales
# 118   39        No                NaN    117,0$                       NaN
# 229   31       Yes  travel_frequently   1445,0$                       NaN
# 130   49        No                NaN   1245,0$                       NaN
# 1032  25        No      travel_rarely    882,0$   Research & Development
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# 268                  8          4               NaN              1
# ...

# %%
df_raw_data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'employeecount',
#        'employeenumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NUMCOMPANIESWORKED',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TOTALWORKINGYEARS', 'TrainingTimesLastYear', 'WORKLIFEBALANCE',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YEARSWITHCURRMANAGER', 'SameAsMonthlyIncome', 'DateBirth', 'Salary',
#        'RoleDepartament', 'NUMBERCHILDREN', 'RemoteWork'],
#       dtype='object')

# %%
# para verlo mejor
df_raw_data.columns.to_list()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'employeecount',
#  'employeenumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NUMCOMPANIESWORKED',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TOTALWORKINGYEARS',
#  'TrainingTimesLastYear',
#  'WORKLIFEBALANCE',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YEARSWITHCURRMANAGER',
#  'SameAsMonthlyIncome',
#  'DateBirth',
#  'Salary',
#  'RoleDepartament',
#  'NUMBERCHILDREN',
#  'RemoteWork']

# %%
# # Calcula estadísticas descriptivas para las columnas
df_raw_data.describe(include='all')
# Out:
#          Age Attrition BusinessTravel DailyRate                Department  \
# count   1614      1614            842      1614                       302
# unique    54         2              3       849                         3
# top       35        No  travel_rarely      nan$   Research & Development
# freq      84      1355            586       124                       196
# mean     NaN       NaN            NaN       NaN                       NaN
# std      NaN       NaN            NaN       NaN                       NaN
# min      NaN       NaN            NaN       NaN                       NaN
# 25%      NaN       NaN            NaN       NaN                       NaN
# 50%      NaN       NaN            NaN       NaN                       NaN
# 75%      NaN       NaN            NaN       NaN                       NaN
# max      NaN       NaN            NaN       NaN                       NaN
#
#         DistanceFromHome    Education EducationField  employeecount  \
# ...

# %%
# Calcula estadísticas descriptivas para las columnas de tipo objeto, T Transpone el resultado para mostrar las estadísticas en filas en lugar de columnas
df_raw_data.describe(include = "object").T
# Out:
#                     count unique                       top  freq
# Age                  1614     54                        35    84
# Attrition            1614      2                        No  1355
# BusinessTravel        842      3             travel_rarely   586
# DailyRate            1614    849                      nan$   124
# Department            302      3   Research & Development    196
# EducationField        869      6             Life Sciences   349
# employeenumber       1183   1079                     482,0     2
# HourlyRate           1614     72             Not Available    84
# JobRole              1614   1579                  mANager      4
# MaritalStatus         963      5                   Married   404
# MonthlyIncome         771    668                    6347,0     4
# Over18                713      1                         Y   713
# OverTime              938      2                        No   682
# ...

# %%
# calcula la frecuencia de cada valor único en la columna 
df_raw_data["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Married     404
# Single      325
# Divorced    188
# Marreid      35
# divorced     11
# Name: count, dtype: int64

# %%
df_raw_data["WORKLIFEBALANCE"].value_counts()
# Out:
# WORKLIFEBALANCE
# 3,0    913
# 2,0    359
# 4,0    155
# 1,0     79
# Name: count, dtype: int64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_raw_data["JobRole"].value_counts()
# Out:
# JobRole
# mANager                       4
# ManageR                       3
# ManagEr                       3
# mAnaGeR                       3
# MANAgER                       3
#                              ..
# ResEArch ScieNTiST            1
# HealthcARE RePreSENtAtiVe     1
# ReSearcH scIEntist            1
# LAbOrATOry techNicIan         1
# mAnUfactURInG DiRECTOr        1
# Name: count, Length: 1579, dtype: int64

# %%
mapear =
df_raw_data["JobRole"].value_counts()

# %%
df_raw_data["RoleDepartament"].value_counts()
# Out:
# RoleDepartament
# MaNAgeR  -  Sales                                        2
# ManaGER  -  Research & Development                       1
# ReseaRch scIENTisT  -  Research & Development            1
# ManufacTURInG DIRECtOR  -  Research & Development        1
# hEalthCaRe reprEseNTaTiVe  -  Research & Development     1
#                                                         ..
# saLES eXEcUTiVE  -  Sales                                1
# mANUfacTURiNG dIRectOR  -  Research & Development        1
# huMAn ResOurces  -  Human Resources                      1
# HUMAN ResoURCeS  -  Human Resources                      1
# sAleS EXECUtIvE  -  Sales                                1
# Name: count, Length: 301, dtype: int64

# %%
# columnas que contienen texto o cadenas USARE : select_dtypes(include="TIPO DE COLUMNA")

df_raw_data_cat = df_raw_data.select_dtypes(include = "object")
df_raw_data_cat.head()
# Out:
#   Age Attrition BusinessTravel DailyRate                Department  \
# 0  51        No            NaN    684,0$                       NaN
# 1  52        No            NaN    699,0$                       NaN
# 2  42        No  travel_rarely    532,0$   Research & Development
# 3  47        No  travel_rarely    359,0$                       NaN
# 4  46        No            NaN   1319,0$                       NaN
#
#      EducationField employeenumber HourlyRate              JobRole  \
# 0               NaN          162,0         51   resEArch DIREcToR
# 1     Life Sciences          259,0         65             ManAGeR
# 2  Technical Degree          319,0         58             ManaGER
# 3           Medical            NaN         82   ReseArCH DIrECtOr
# 4  Technical Degree            NaN         45     sAleS EXECUtIve
#
#   MaritalStatus MonthlyIncome Over18 OverTime PerformanceRating StandardHours  \
# 0           NaN       19537,0      Y       No               3,0           NaN
# ...

# %% [markdown]
# Uso de isnull y Sum : devuelve el número de filas que no tienen un valor válido (es decir, están vacías o son nulas)

# %%
df_raw_data["MaritalStatus"].isnull().sum()
# Out:
# 651

# %%
df_raw_data["Salary"].isnull().sum()
# Out:
# 0

# %%
df_raw_data["NUMBERCHILDREN"].isnull().sum()
# Out:
# 1614

# %% [markdown]
# Uso duplicated(): Por defecto, marca como False la primera ocurrencia de cada conjunto de valores duplicados y todas las demás como True

# %%
df_raw_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1609    False
# 1610    False
# 1611    False
# 1612    False
# 1613    False
# Length: 1614, dtype: bool

# %% [markdown]
# duplicated(): calcula la cantidad de filas duplicadas

# %%
df_raw_data.duplicated().sum()
# Out:
# 0

# %%
# subset para poner una columna especifica

df_raw_data.duplicated(subset = "MaritalStatus").sum()
# Out:
# 1608

# %%
df_raw_data.duplicated(subset = "HourlyRate").sum()
# Out:
# 1542
